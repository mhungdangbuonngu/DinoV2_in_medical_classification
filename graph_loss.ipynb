# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_json("E:/GitHub/DinoV2_in_medical_classification/model_eval/overall_loss.json")
data=np.mean(data,axis=0)
data.shape
# Out:
# (100,)

# %%
plt.figure(figsize=(10, 5))
plt.plot(data, label='Loss', color='blue')
plt.title('Loss Graph')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()
