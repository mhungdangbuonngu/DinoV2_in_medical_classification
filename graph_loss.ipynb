# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
epoch_loss=np.load('E:\GitHub\DinoV2_in_medical_classification\model_eval\epoch_loss.npy')
epoch_loss
# Out:
# array([0.73894989])

# %%
batch_loss=np.load("E:/GitHub/DinoV2_in_medical_classification/model_eval/batch_loss.npy")
batch_loss
# Out:
# array([0.7583378 , 0.75514966, 0.74545956, 0.75884068, 0.75993282,
#        0.74197954, 0.7466749 , 0.7594862 , 0.76100957, 0.73894989])

# %%
plt.figure(figsize=(8,6))
plt.plot(batch_loss,label='batch_loss',color='blue',marker='o')
plt.xlabel('batch')
plt.ylabel('loss')
plt.title('batch loss during training')
plt.grid(True)
plt.legend()
plt.show()
